# %%
#!pip install numpy

# %%
import matplotlib.pyplot as plt
import numpy

x = [1,2,3,4]
y = [1,4,2,3]

fig, ax = plt.subplots()
ax.plot(x,y, label ='data')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('simple plot')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y1 = [1,3.8, 2, 2.5]
y2 = [1,2,3,4]

fig, ax = plt.subplots()
ax.plot(x,  y1, label='data1')
ax.plot(x, y2, label='data2')

ax.set_xlabel('x label')
ax.set_ylabel('y label')

ax.set_title('simple plot')

ax.legend()

ax.grid(color='red', alpha=0.2)
ax.spines['right'].set_color('blue')
ax.spines['right'].set_linestyle('-.')

from matplotlib.ticker import MultipleLocator, FormatStrFormatter
ax.xaxis.set_major_locator(MultipleLocator(0.5))
ax.xaxis.set_major_formatter(FormatStrFormatter('%1.1f'))
ax.xaxis.set_minor_locator(MultipleLocator(0.1))

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y1 = [1,3.8, 2, 2.5]
y2 = [1,2,3,4]

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(9,3), sharey=True)
ax.plot(x,  y1, label='data1')
ax.plot(x, y2, label='data2')

ax.set_xlabel('x label')
ax.set_ylabel('y label')

ax.set_title('simple plot')

ax.legend()

ax.grid(color='red', alpha=0.2)
ax.spines['right'].set_color('blue')
ax.spines['right'].set_linestyle('-.')

from matplotlib.ticker import MultipleLocator, FormatStrFormatter
ax.xaxis.set_major_locator(MultipleLocator(0.5))
ax.xaxis.set_major_formatter(FormatStrFormatter('%1.1f'))
ax.xaxis.set_minor_locator(MultipleLocator(0.1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [8], line 8
#       5 y2 = [1,2,3,4]
#       7 fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(9,3), sharey=True)
# ----> 8 ax.plot(x,  y1, label='data1')
#       9 ax.plot(x, y2, label='data2')
#      11 ax.set_xlabel('x label')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
import matplotlib.pyplot as plt
data = {'apple': 10, 'orange':15, 'lemon':5}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(9,3), sharey=True)

axs[0, 0].bar(names, values, color=['black', 'red', 'green'])
axs[0,1].scatter(names, values)
axs[0, 2].plot(names, values)
fig.suptitle('Categoricla plotting')

plt.show()
