# %%
'''
rgb and rgba 
'''
from PIL import Image

im = Image.open('example.png')
print(im.format, im.size, im.mode)
im
# Out:
# PNG (679, 384) RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=679x384 at 0x7FB198266340>

# %%
Image.open('example.png').resize((48,27)).resize((480, 270), resample=Image.BILINEAR)
Image.open('example.png').resize((48,27)).resize((480, 270), resample=Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGBA size=480x270 at 0x7FB1981F6EB0>

# %%
Image.open('example.png').crop((520,180,640,480))
# Out:
# <PIL.Image.Image image mode=RGBA size=120x300 at 0x7FB19821ED90>

# %%
im = Image.open('example.png')
print(im.format, im.size, im.mode)
cropped = im.crop((520, 180,640,480))
im.paste(cropped, (400,180,520,480))
im
# Out:
# PNG (679, 384) RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=679x384 at 0x7FB1981F6AC0>

# %%
im = Image.open('example.png').rotate(45)
im
# Out:
# <PIL.Image.Image image mode=RGBA size=679x384 at 0x7FB189475880>

# %%
from PIL import Image, ImageEnhance, ImageDraw

enhancer  = ImageEnhance.Sharpness(im)
im = enhancer.enhance(5)
im
# Out:
# <PIL.Image.Image image mode=RGBA size=679x384 at 0x7FB189475C10>

# %%
with Image.open('example.png').convert('RGBA') as base:
    im = Image.open('example.png').rotate(45)
    overlay = Image.new('RGBA', base.size,(0,0,0,0))
    draw = ImageDraw.Draw(overlay)
    x,y,w,h = (520, 180,640,480)
    draw.rectangle(
        (x,y,x+w, y+h), outline=(0,0,255,128),
        fill = (0,0,255,30) #alpha = 30 

    )
    comp = Image.alpha_composite(base, overlay)
comp
# Out:
# <PIL.Image.Image image mode=RGBA size=679x384 at 0x7FB1894B3BB0>
